# %%
import pandas as pd
from fancyimpute import IterativeImputer
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, KFold, ParameterGrid, ParameterSampler
import numpy as np
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.feature_selection import RFE, RFECV
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.wrappers.scikit_learn import KerasRegressor

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

train = pd.read_csv('https://raw.githubusercontent.com/casperbh96/house-price-prediction/master/Experimental/data/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/casperbh96/house-price-prediction/master/Experimental/data/test.csv')

def fill_ii(df):
    df_filled_ii = pd.DataFrame(IterativeImputer().fit_transform(df.values))
    df_filled_ii.columns = df.columns
    df_filled_ii.index = df.index

    return df_filled_ii

def data_engineering(train, test):
    train = train.drop(train.index[0])
    
    cc_data = pd.concat([train, test], sort=True)
    cc_data = cc_data.drop(['Id', 'SalePrice','Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], axis=1)
    
    train["SalePrice"] = np.log1p(train["SalePrice"])
    y = train['SalePrice']
    
    cc_data = pd.get_dummies(cc_data, prefix_sep='_')
    
    cc_data = fill_ii(cc_data)
    
    X_train = cc_data[:train.shape[0]]
    X_test = cc_data[train.shape[0]:]
    
    return X_train,X_test,y

X,X_test,y = data_engineering(train,test)
# Out:
# Using TensorFlow backend.

# %%
class NestedCV():
    '''A general class to handle nested cross-validation for any estimator that
    implements the scikit-learn estimator interface.

    Parameters
    ----------
    model : estimator
        The estimator implements scikit-learn estimator interface.

    params_grid : dict
        The dict contains hyperparameters for model.

    outer_kfolds : int
        Number of outer K-partitions in KFold

    inner_kfolds : int
        Number of inner K-partitions in KFold

    cv_options: dict, default = {}
        Nested CV Options, check docs for details.

        metric : callable from sklearn.metrics, default = mean_squared_error
            A scoring metric used to score each model

        metric_score_indicator_lower : boolean, default = True
            Choose whether lowe score is better for the metric calculation or hight score is better, `True` means lower score is better.

        sqrt_of_score : boolean, default = False
            Whether or not if the square root should be taken of score

        randomized_search : boolean, default = True
            Whether to use gridsearch or randomizedsearch from sklearn

        randomized_search_iter : int, default = 10
            Number of iterations for randomized search

        recursive_feature_elimination : boolean, default = False
            Whether to do feature elimination
    '''

    def __init__(self, model, params_grid, outer_kfolds, inner_kfolds, cv_options={}):
        self.model = model
        self.params_grid = params_grid
        self.outer_kfolds = outer_kfolds
        self.inner_kfolds = inner_kfolds
        self.metric = cv_options.get('metric', mean_squared_error)
        self.metric_score_indicator_lower = cv_options.get(
            'metric_score_indicator_lower', True)
        self.sqrt_of_score = cv_options.get('sqrt_of_score', False)
        self.randomized_search = cv_options.get('randomized_search', True)
        self.randomized_search_iter = cv_options.get(
            'randomized_search_iter', 10)
        self.recursive_feature_elimination = cv_options.get(
            'recursive_feature_elimination', False)
        self.outer_scores = []
        self.best_params = {}
        self.best_inner_score_list = []
        self.variance = []

    # to check if use sqrt_of_score and handle the different cases
    def _transform_score_format(self, scoreValue):
        if self.sqrt_of_score:
            return np.sqrt(scoreValue)
        return scoreValue

    # to convert array of dict to dict with array values, so it can be used as params for parameter tuning
    def _score_to_best_params(self, best_inner_params_list):
        params_dict = {}
        for best_inner_params in best_inner_params_list:
            for key, value in best_inner_params.items():
                if key in params_dict:
                    if value not in params_dict[key]:
                        params_dict[key].append(value)
                else:
                    params_dict[key] = [value]
        return params_dict

    # a method to handle  recursive feature elimination
    def _fit_recursive_feature_elimination(self, best_inner_params, X_train_outer, y_train_outer, X_test_outer):
        print('\nRunning recursive feature elimination for outer loop... (SLOW)')
        # K-fold (inner_kfolds) recursive feature elimination
        rfe = RFECV(estimator=self.model, min_features_to_select=20,
                    scoring='neg_mean_squared_error', cv=self.inner_kfolds, n_jobs=-1)
        rfe.fit(X_train_outer, y_train_outer)

        # Assign selected features to data
        print('Best number of features was: {0}'.format(rfe.n_features_))
        X_train_outer_rfe = rfe.transform(X_train_outer)
        X_test_outer_rfe = rfe.transform(X_test_outer)

        # Train model with best inner parameters on the outer split
        self.model.set_params(**best_inner_params)
        self.model.fit(X_train_outer_rfe, y_train_outer)
        return self.model.predict(X_test_outer_rfe)

    def fit(self, X, y):
        '''A method to fit nested cross-validation 
        Parameters
        ----------
        X : pandas dataframe (rows, columns)
            Training dataframe, where rows is total number of observations and columns
            is total number of features
    
        y : pandas dataframe
            Output dataframe, also called output variable. y is what you want to predict.
    
        Returns
        -------
        It will not return directly the values, but it's accessable from the class object it self.
        You should be able to access:
        
        variance
            Model variance by numpy.var()
            
        outer_scores 
            Outer score List.
            
        best_inner_score_list 
            Best inner scores for each outer loop
            
        best_params 
            All best params from each inner loop cumulated in a dict
            
        best_inner_params_list 
            Best inner params for each outer loop as an array of dictionaries
        '''
    
        print('\n{0} <-- Running this model now'.format(type(self.model).__name__))
        outer_cv = KFold(n_splits=self.outer_kfolds, shuffle=True)
        inner_cv = KFold(n_splits=self.inner_kfolds, shuffle=True)
        model = self.model
    
        outer_scores = []
        variance = []
        best_inner_params_list = []  # Change both to by one thing out of key-value pair
        best_inner_score_list = []
    
        # Split X and y into K-partitions to Outer CV
        for (i, (train_index, test_index)) in enumerate(outer_cv.split(X, y)):
            print('\n{0}/{1} <-- Current outer fold'.format(i+1, self.outer_kfolds))
            X_train_outer, X_test_outer = X.iloc[train_index], X.iloc[test_index]
            y_train_outer, y_test_outer = y.iloc[train_index], y.iloc[test_index]
            best_inner_params = {}
            best_inner_score = None
    
            # Split X_train_outer and y_train_outer into K-partitions to be inner CV
            for (j, (train_index_inner, test_index_inner)) in enumerate(inner_cv.split(X_train_outer, y_train_outer)):
                print('\n\t{0}/{1} <-- Current inner fold'.format(j+1, self.inner_kfolds))
                X_train_inner, X_test_inner = X_train_outer.iloc[
                    train_index_inner], X_train_outer.iloc[test_index_inner]
                y_train_inner, y_test_inner = y_train_outer.iloc[
                    train_index_inner], y_train_outer.iloc[test_index_inner]
    
                # Run either RandomizedSearch or GridSearch for input parameters
                for param_dict in ParameterSampler(param_distributions=self.params_grid, 
                                                   n_iter=self.randomized_search_iter) if (self.randomized_search) else (
                                                           ParameterGrid(param_grid=self.params_grid)):
                    # Set parameters, train model on inner split, predict results.
                    if(type(self.model).__name__ == 'KerasRegressor'):
                        with tf.device('/gpu:0'):
                          model.set_params(**param_dict)
                          model.fit(X_train_inner, y_train_inner)
                    else:
                      model.set_params(**param_dict)
                      model.fit(X_train_inner, y_train_inner)
                    
                    
                    inner_pred = model.predict(X_test_inner)
                    inner_grid_score = self.metric(y_test_inner, inner_pred)
                    current_inner_score_value = best_inner_score
                    # Find best score and corresponding best grid
                    if(best_inner_score is not None):
                        if(self.metric_score_indicator_lower and best_inner_score > inner_grid_score):
                            best_inner_score = self._transform_score_format(inner_grid_score)
                            
                        elif (not self.metric_score_indicator_lower and best_inner_score < inner_grid_score):
                            best_inner_score = self._transform_score_format(inner_grid_score)
                    else:
                        best_inner_score = self._transform_score_format(inner_grid_score)
                        current_inner_score_value = best_inner_score+1  # first time random thing
                        
                    # Update best_inner_grid once rather than calling it under each if statement
                    if(current_inner_score_value is not None and current_inner_score_value != best_inner_score):
                        best_inner_params = param_dict
    
            best_inner_params_list.append(best_inner_params)
            best_inner_score_list.append(best_inner_score)
    
            if self.recursive_feature_elimination:
                pred = self._fit_recursive_feature_elimination(
                    best_inner_params, X_train_outer, y_train_outer, X_test_outer)
            else:
                # Train model with best inner parameters on the outer split
                model.set_params(**best_inner_params)
                model.fit(X_train_outer, y_train_outer)
                pred = model.predict(X_test_outer)
    
            outer_scores.append(self._transform_score_format(
                self.metric(y_test_outer, pred)))
    
            # Append variance
            variance.append(np.var(pred, ddof=1))
    
            print('\nResults for outer fold:\nBest inner parameters was: {0}'.format(
                best_inner_params_list[i]))
            print('Outer score: {0}'.format(outer_scores[i]))
            print('Inner score: {0}'.format(best_inner_score_list[i]))
    
        self.variance = variance
        self.outer_scores = outer_scores
        self.best_inner_score_list = best_inner_score_list
        self.best_params = self._score_to_best_params(best_inner_params_list)
        self.best_inner_params_list = best_inner_params_list

    # Method to show score vs variance chart. You can run it only after fitting the model.
    def score_vs_variance_plot(self):
        # Plot score vs variance
        plt.figure()
        plt.subplot(211)

        variance_plot, = plt.plot(self.variance, color='b')
        score_plot, = plt.plot(self.outer_scores, color='r')

        plt.legend([variance_plot, score_plot],
                   ["Variance", "Score"],
                   bbox_to_anchor=(0, .4, .5, 0))

        plt.title("{0}: Score VS Variance".format(type(self.model).__name__),
                  x=.5, y=1.1, fontsize="15")

# %%
#NestedCV parameters
NUM_TRIALS = 50
outerFolds = 5
innerFolds = 5

models_to_run = [RandomForestRegressor()]
models_param_grid = [
                    { # 2nd param grid, corresponding to RandomForestRegressor
                            'max_depth': [3, None],
                            'n_estimators': [100,200,300,400,500,600,700,800,900,1000],
                            'max_features' : [50,100,150,200]
                    }
                    ]
RF_scores = []

# %%
for trial in range(NUM_TRIALS):
    print('Running {0} / {1}'.format(trial,NUM_TRIALS))
    for i,model in enumerate(models_to_run):
        nested_CV_search = NestedCV(model=model, params_grid=models_param_grid[i], outer_kfolds=outerFolds, inner_kfolds=innerFolds, 
                          cv_options={'sqrt_of_score':True, 'randomized_search_iter':30})
        nested_CV_search.fit(X=X,y=y)
        model_param_grid = nested_CV_search.best_params
        print('\nCumulated best parameter grids was:\n{0}'.format(model_param_grid))
        
        gscv = GridSearchCV(estimator=model,param_grid=model_param_grid,scoring='neg_mean_squared_error',cv=5, n_jobs=-1)
        gscv.fit(X,y)
        
        print('\nFitting with optimal parameters:\n{0}'.format(gscv.best_params_))
        gscv.predict(X_test)
        score = np.sqrt(-gscv.best_score_)
        
        if(type(model).__name__ == 'KerasRegressor'):
            NN_scores.append(score)
        elif(type(model).__name__ == 'RandomForestRegressor'):
            RF_scores.append(score)
        elif(type(model).__name__ == 'XGBRegressor'):
            XGB_scores.append(score)
        
        print('\nFinal score for {0} was {1}'.format(type(model).__name__,score))
# Out:
# Running 0 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 200, 'max_depth': None}
# Outer score: 0.1324461727009845
# Inner score: 0.12010102625556887
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18289988592716283
# Inner score: 0.18846491063509818
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.1950136077880771
# Inner score: 0.17991531891460852
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19491830568616753
# Inner score: 0.19066672357648215
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14431950632210563
# Inner score: 0.12295634671385641
#
# Cumulated best parameter grids was:
# {'n_estimators': [600, 400, 100, 500], 'max_features': [200, 50, 150], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 600}
#
# Final score for RandomForestRegressor was 0.13776257350306176
# Running 1 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18089722085320525
# Inner score: 0.18320838518466734
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.19750667475320668
# Inner score: 0.1926493091664514
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.18287960367762016
# Inner score: 0.18596675013428382
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 50, 'max_depth': None}
# Outer score: 0.13960159209456627
# Inner score: 0.14234806913058773
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 150, 'max_depth': None}
# Outer score: 0.13286308780993025
# Inner score: 0.11895389968870199
#
# Cumulated best parameter grids was:
# {'n_estimators': [1000, 200, 600, 800, 900], 'max_features': [150, 100, 50], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13771936883560157
# Running 2 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.19443093942070203
# Inner score: 0.21693389263184756
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.19565069479813574
# Inner score: 0.19278663083234332
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 150, 'max_depth': None}
# Outer score: 0.15964515230273532
# Inner score: 0.1612048451095132
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.1642736649433841
# Inner score: 0.20952512729044484
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13347990650617741
# Inner score: 0.14144885434840715
#
# Cumulated best parameter grids was:
# {'n_estimators': [600, 900, 300, 500, 200], 'max_features': [100, 50, 150, 200], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 300}
#
# Final score for RandomForestRegressor was 0.13748449992886144
# Running 3 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 100, 'max_depth': None}
# Outer score: 0.1445642051197123
# Inner score: 0.14526029591811007
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.2027191203850779
# Inner score: 0.18704352727937087
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.18785783896776798
# Inner score: 0.19008432740471967
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 150, 'max_depth': None}
# Outer score: 0.13748072481239762
# Inner score: 0.1641761235664769
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14281731530123978
# Inner score: 0.13451832345894793
#
# Cumulated best parameter grids was:
# {'n_estimators': [100, 1000], 'max_features': [100, 50, 150], 'max_depth': [None, 3]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 1000}
#
# Final score for RandomForestRegressor was 0.13801303330088446
# Running 4 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.1853699670541885
# Inner score: 0.18342208275149777
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17940260426160687
# Inner score: 0.1846935817531719
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': None}
# Outer score: 0.14831874471683507
# Inner score: 0.1398709895326425
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19707398700107845
# Inner score: 0.21610884102189093
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.21282967558825097
# Inner score: 0.19184167584274994
#
# Cumulated best parameter grids was:
# {'n_estimators': [200, 600, 800, 400], 'max_features': [200, 150], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 150, 'n_estimators': 800}
#
# Final score for RandomForestRegressor was 0.1380739891941768
# Running 5 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 200, 'max_depth': None}
# Outer score: 0.12696449070165622
# Inner score: 0.15544584674447812
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.2028445515122212
# Inner score: 0.1809901883466042
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 100, 'max_depth': None}
# Outer score: 0.1294596093291734
# Inner score: 0.1462147641654608
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 100, 'max_depth': None}
# Outer score: 0.15548160127110763
# Inner score: 0.1428793255137231
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.17602623843369436
# Inner score: 0.19594377324633028
#
# Cumulated best parameter grids was:
# {'n_estimators': [100, 600, 300, 900, 800], 'max_features': [200, 100], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13740326228581137
# Running 6 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18141021827094003
# Inner score: 0.18891179942240163
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.21858484049095736
# Inner score: 0.19885076645776448
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13954063542640668
# Inner score: 0.14681311369811784
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 50, 'max_depth': None}
# Outer score: 0.13329351927545505
# Inner score: 0.13304668227715488
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.19254709969241604
# Inner score: 0.18093982572864914
#
# Cumulated best parameter grids was:
# {'n_estimators': [1000, 900, 300], 'max_features': [200, 50, 150], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 1000}
#
# Final score for RandomForestRegressor was 0.13804475950328707
# Running 7 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17346611343423377
# Inner score: 0.17555049148185728
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 200, 'max_depth': None}
# Outer score: 0.1505160850282049
# Inner score: 0.14247087813077008
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.20244461709535053
# Inner score: 0.19117553350320748
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 100, 'max_depth': None}
# Outer score: 0.1311921784685817
# Inner score: 0.15217545084839115
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.20030529715798073
# Inner score: 0.1831416203111501
#
# Cumulated best parameter grids was:
# {'n_estimators': [1000, 300, 700, 900], 'max_features': [150, 200, 50, 100], 'max_depth': [3, None]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 1000}
#
# Final score for RandomForestRegressor was 0.13728544572517265
# Running 8 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 50, 'max_depth': None}
# Outer score: 0.13950037049359731
# Inner score: 0.15282611902191062
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.20888348350358507
# Inner score: 0.19695854445677893
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18819519305119417
# Inner score: 0.21053778599341763
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.16629099107025025
# Inner score: 0.1905650004403608
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18922597775490696
# Inner score: 0.21719713253620931
#
# Cumulated best parameter grids was:
# {'n_estimators': [1000, 200, 600, 100], 'max_features': [50, 150, 200], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 600}
#
# Final score for RandomForestRegressor was 0.1382407880208539
# Running 9 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14213758351562372
# Inner score: 0.13053285394936703
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 100, 'max_depth': None}
# Outer score: 0.12978678545961836
# Inner score: 0.12510033070025067
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.20613624050054768
# Inner score: 0.17585517383381075
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 150, 'max_depth': None}
# Outer score: 0.1394467962128608
# Inner score: 0.15644377562785938
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14250579884503511
# Inner score: 0.12813835478049676
#
# Cumulated best parameter grids was:
# {'n_estimators': [500, 200, 900, 800], 'max_features': [150, 100, 50], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13757193585815183
# Running 10 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.18946437205385638
# Inner score: 0.18639658991607455
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.19639686095307352
# Inner score: 0.17998500028863934
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.18228888018182168
# Inner score: 0.21435555928309252
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': None}
# Outer score: 0.1682743832999859
# Inner score: 0.16468742584347196
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 100, 'max_depth': None}
# Outer score: 0.125988289969654
# Inner score: 0.13508883447183634
#
# Cumulated best parameter grids was:
# {'n_estimators': [200, 600, 700, 400, 900], 'max_features': [50, 200, 100], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 700}
#
# Final score for RandomForestRegressor was 0.1373049460526052
# Running 11 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.198342370316624
# Inner score: 0.16104485052442796
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 50, 'max_depth': None}
# Outer score: 0.16518003487540625
# Inner score: 0.10851062551372119
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.1842676386781784
# Inner score: 0.19889430173736178
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17641784787325338
# Inner score: 0.19728924575790224
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17615677800568177
# Inner score: 0.18078070645872163
#
# Cumulated best parameter grids was:
# {'n_estimators': [500, 700, 300, 400], 'max_features': [150, 50], 'max_depth': [3, None]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 400}
#
# Final score for RandomForestRegressor was 0.13791689063380574
# Running 12 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 200, 'max_depth': None}
# Outer score: 0.1320327258522347
# Inner score: 0.12473598580843302
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.19479645670616702
# Inner score: 0.180014364256281
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 50, 'max_depth': None}
# Outer score: 0.1284543909246676
# Inner score: 0.16571984580588697
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.20833169828284256
# Inner score: 0.178069649717582
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18032064677227103
# Inner score: 0.2060861700861147
#
# Cumulated best parameter grids was:
# {'n_estimators': [700, 300, 1000], 'max_features': [200, 100, 50], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 1000}
#
# Final score for RandomForestRegressor was 0.1374978277611055
# Running 13 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 200, 'max_depth': None}
# Outer score: 0.16402460334422328
# Inner score: 0.17466122651336682
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 150, 'max_depth': None}
# Outer score: 0.12637105606984497
# Inner score: 0.12854836705521716
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 100, 'max_depth': None}
# Outer score: 0.14558719272081655
# Inner score: 0.14660134105279407
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.18611472670678564
# Inner score: 0.1741198041527365
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.1960650718959349
# Inner score: 0.21578086882283617
#
# Cumulated best parameter grids was:
# {'n_estimators': [1000, 700, 600, 900], 'max_features': [200, 150, 100, 50], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 600}
#
# Final score for RandomForestRegressor was 0.1375402207481577
# Running 14 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.2020901013597557
# Inner score: 0.18146345364883243
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13768972191373716
# Inner score: 0.16073320993266388
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.17105632354621703
# Inner score: 0.22953775600043178
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.1689939767275281
# Inner score: 0.16139316315709532
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 200, 'max_depth': None}
# Outer score: 0.15264241243377225
# Inner score: 0.14365178602071418
#
# Cumulated best parameter grids was:
# {'n_estimators': [500, 400, 900, 200, 100], 'max_features': [200, 100], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13769138732871372
# Running 15 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18234036211102297
# Inner score: 0.2122755855545936
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18998458048157232
# Inner score: 0.19939959106410693
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': None}
# Outer score: 0.1340497280021343
# Inner score: 0.1301564815091026
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.1889163222117124
# Inner score: 0.21710703844682214
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 100, 'max_depth': None}
# Outer score: 0.14593401745071302
# Inner score: 0.14734067755632604
#
# Cumulated best parameter grids was:
# {'n_estimators': [800, 200, 900, 700, 500], 'max_features': [150, 200, 50, 100], 'max_depth': [3, None]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13747128829598093
# Running 16 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.17936177839737572
# Inner score: 0.180262785446419
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.17728452883142037
# Inner score: 0.20958662377298368
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 50, 'max_depth': None}
# Outer score: 0.13557914332374718
# Inner score: 0.14008672889383905
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 100, 'max_depth': None}
# Outer score: 0.16465091020163902
# Inner score: 0.14288163204508839
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17552967892874904
# Inner score: 0.20170798591225536
#
# Cumulated best parameter grids was:
# {'n_estimators': [700, 900, 200, 800], 'max_features': [50, 100, 150], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.1376112414052873
# Running 17 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.18074226403954255
# Inner score: 0.18262935232023922
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 100, 'max_depth': None}
# Outer score: 0.12971950712720626
# Inner score: 0.13719450290998694
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 100, 'max_depth': None}
# Outer score: 0.12119393680342977
# Inner score: 0.13402623901503516
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 150, 'max_depth': None}
# Outer score: 0.15054706563496228
# Inner score: 0.13186174720237315
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 150, 'max_depth': None}
# Outer score: 0.1531321811183537
# Inner score: 0.11728945223065809
#
# Cumulated best parameter grids was:
# {'n_estimators': [400, 100, 200], 'max_features': [100, 150], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 400}
#
# Final score for RandomForestRegressor was 0.13799079409170906
# Running 18 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.193116235287631
# Inner score: 0.19680655495955668
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': None}
# Outer score: 0.15493166995710242
# Inner score: 0.10298052205765537
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17306833671963576
# Inner score: 0.18582377944955994
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.20169807700556133
# Inner score: 0.1922595444669559
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.19332573675987644
# Inner score: 0.2167306663052164
#
# Cumulated best parameter grids was:
# {'n_estimators': [100, 800, 400, 300], 'max_features': [50, 200, 150], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 150, 'n_estimators': 800}
#
# Final score for RandomForestRegressor was 0.13852738377144166
# Running 19 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19554458297009392
# Inner score: 0.20778381872322177
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 200, 'max_depth': None}
# Outer score: 0.12651877022914804
# Inner score: 0.14013486248373547
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': None}
# Outer score: 0.18501995108951855
# Inner score: 0.12691232782063624
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 50, 'max_depth': None}
# Outer score: 0.12776526424794735
# Inner score: 0.1392375422631719
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.17313348344617896
# Inner score: 0.20414785854222514
#
# Cumulated best parameter grids was:
# {'n_estimators': [700, 200, 400, 1000, 600], 'max_features': [200, 50, 100], 'max_depth': [3, None]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 700}
#
# Final score for RandomForestRegressor was 0.13767782781143456
# Running 20 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.18455426720204066
# Inner score: 0.2214893245445115
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.19006480991224645
# Inner score: 0.1853297763297608
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13266340282445652
# Inner score: 0.13025588867254673
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': None}
# Outer score: 0.14909942457634862
# Inner score: 0.152555197648569
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13181600055444617
# Inner score: 0.15260939392491296
#
# Cumulated best parameter grids was:
# {'n_estimators': [500, 700, 800, 300], 'max_features': [100, 200], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 700}
#
# Final score for RandomForestRegressor was 0.1373861097048895
# Running 21 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 100, 'max_depth': None}
# Outer score: 0.1406944634757136
# Inner score: 0.16570048737663315
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19668131904651456
# Inner score: 0.18868267021117796
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19253166869955604
# Inner score: 0.17973266224884976
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 100, 'max_depth': None}
# Outer score: 0.13062275564734097
# Inner score: 0.16918214432632986
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.1827840184530192
# Inner score: 0.20432307804812674
#
# Cumulated best parameter grids was:
# {'n_estimators': [800, 500, 100, 700], 'max_features': [100, 200, 50], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 700}
#
# Final score for RandomForestRegressor was 0.13707683006881313
# Running 22 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.17956302213983077
# Inner score: 0.17313739654328056
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.19926859135757397
# Inner score: 0.20356993748834912
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 1000, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.19078003096116802
# Inner score: 0.18284780844047474
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18806926021662707
# Inner score: 0.20361705353445644
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# ...
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18312692671789454
# Inner score: 0.1847166313926798
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.16823851486822788
# Inner score: 0.19927880856335078
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 100, 'max_depth': None}
# Outer score: 0.15283748981057801
# Inner score: 0.12716890400313066
#
# Cumulated best parameter grids was:
# {'n_estimators': [400, 1000, 100, 600], 'max_features': [200, 150, 100], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 400}
#
# Final score for RandomForestRegressor was 0.13773408870285855
# Running 43 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.18029579335189214
# Inner score: 0.17655301850813468
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 200, 'max_features': 50, 'max_depth': None}
# Outer score: 0.12945988376247314
# Inner score: 0.12497792365540096
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18784779660316706
# Inner score: 0.1825979654285822
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14468597936801872
# Inner score: 0.15501142000304785
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.20688358000002255
# Inner score: 0.1829719822559027
#
# Cumulated best parameter grids was:
# {'n_estimators': [600, 200, 500, 400, 700], 'max_features': [100, 50, 200, 150], 'max_depth': [3, None]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 200}
#
# Final score for RandomForestRegressor was 0.1374885900275835
# Running 44 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 50, 'max_depth': None}
# Outer score: 0.15012981296086408
# Inner score: 0.1378137955280353
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.1770648190698234
# Inner score: 0.20334308074055757
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 150, 'max_depth': None}
# Outer score: 0.13405537961449265
# Inner score: 0.16587471594242675
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.205725776667515
# Inner score: 0.18680884762994227
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.2174921305523128
# Inner score: 0.17848386942570252
#
# Cumulated best parameter grids was:
# {'n_estimators': [900, 400, 600, 800], 'max_features': [50, 200, 150], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 900}
#
# Final score for RandomForestRegressor was 0.13790078220249294
# Running 45 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.17859576510778774
# Inner score: 0.17892286407030958
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 400, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14163456287601467
# Inner score: 0.13258653928196937
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.18657038759780098
# Inner score: 0.19237538801004964
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 50, 'max_depth': None}
# Outer score: 0.12577636955623483
# Inner score: 0.16577383016195
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 50, 'max_depth': None}
# Outer score: 0.16239678407787198
# Inner score: 0.15601876016450444
#
# Cumulated best parameter grids was:
# {'n_estimators': [400, 500, 100, 300], 'max_features': [200, 150, 50], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 500}
#
# Final score for RandomForestRegressor was 0.13819065639820635
# Running 46 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.1937565303961831
# Inner score: 0.17980752204599232
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.20465542727111044
# Inner score: 0.18210901092823084
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 150, 'max_depth': None}
# Outer score: 0.14006429445794683
# Inner score: 0.1566994165863406
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 50, 'max_depth': None}
# Outer score: 0.14328293308051088
# Inner score: 0.1420852256501462
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.17402401530263553
# Inner score: 0.20845242999297972
#
# Cumulated best parameter grids was:
# {'n_estimators': [800, 100, 500], 'max_features': [100, 150, 50], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 800}
#
# Final score for RandomForestRegressor was 0.13768789739698498
# Running 47 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 600, 'max_features': 200, 'max_depth': None}
# Outer score: 0.14032649637912267
# Inner score: 0.13864575413461308
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 100, 'max_depth': 3}
# Outer score: 0.1877679207544305
# Inner score: 0.1742417616954295
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.188218554531936
# Inner score: 0.18114120486847146
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 50, 'max_depth': None}
# Outer score: 0.12532100318268607
# Inner score: 0.15491875170566732
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 500, 'max_features': 50, 'max_depth': None}
# Outer score: 0.14151595045281407
# Inner score: 0.13523265306907142
#
# Cumulated best parameter grids was:
# {'n_estimators': [600, 500, 800, 300], 'max_features': [200, 100, 50], 'max_depth': [None, 3]}
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 100, 'n_estimators': 800}
#
# Final score for RandomForestRegressor was 0.13767690772715557
# Running 48 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.18162333658970245
# Inner score: 0.19338390322156973
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 900, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.17534562022127614
# Inner score: 0.1826559968011616
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.21244828330456464
# Inner score: 0.177549258791604
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 300, 'max_features': 200, 'max_depth': None}
# Outer score: 0.1329295460198493
# Inner score: 0.14706915336749837
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 50, 'max_depth': 3}
# Outer score: 0.20329223885532635
# Inner score: 0.1929499419744415
#
# Cumulated best parameter grids was:
# {'n_estimators': [100, 900, 700, 300], 'max_features': [150, 200, 50], 'max_depth': [3, None]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 50, 'n_estimators': 300}
#
# Final score for RandomForestRegressor was 0.13812549238495894
# Running 49 / 50
#
# RandomForestRegressor <-- Running this model now
#
# 1/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 700, 'max_features': 150, 'max_depth': None}
# Outer score: 0.12885860900582072
# Inner score: 0.14055010068344206
#
# 2/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': 3}
# Outer score: 0.19454879798928146
# Inner score: 0.19855209512927532
#
# 3/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13598329199176243
# Inner score: 0.14420987952776437
#
# 4/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 800, 'max_features': 200, 'max_depth': None}
# Outer score: 0.13163626864778488
# Inner score: 0.14685395256342199
#
# 5/5 <-- Current outer fold
#
# 	1/5 <-- Current inner fold
#
# 	2/5 <-- Current inner fold
#
# 	3/5 <-- Current inner fold
#
# 	4/5 <-- Current inner fold
#
# 	5/5 <-- Current inner fold
#
# Results for outer fold:
# Best inner parameters was: {'n_estimators': 100, 'max_features': 150, 'max_depth': 3}
# Outer score: 0.20996264301643136
# Inner score: 0.18506917376615073
#
# Cumulated best parameter grids was:
# {'n_estimators': [700, 800, 100], 'max_features': [150, 200], 'max_depth': [None, 3]}
#
# Fitting with optimal parameters:
# {'max_depth': None, 'max_features': 150, 'n_estimators': 700}
#
# Final score for RandomForestRegressor was 0.1383888606713009

# %%
plt.figure()

rf, = plt.plot(RF_scores, color='b')

plt.legend([rf],
           ["Random Forest"],
           bbox_to_anchor=(0, .4, .5, 0))

plt.title('Test scores as RMSLE with hyperparameter optimization',
          x=.5, y=1.1, fontsize="15")
# Out:
# Text(0.5, 1.1, 'Test scores as RMSLE with hyperparameter optimization')

# %%
print(RF_scores)
print('Random Forest generalization score: {0}'.format(np.mean(RF_scores)))
# Out:
# [0.13776257350306176, 0.13771936883560157, 0.13748449992886144, 0.13801303330088446, 0.1380739891941768, 0.13740326228581137, 0.13804475950328707, 0.13728544572517265, 0.1382407880208539, 0.13757193585815183, 0.1373049460526052, 0.13791689063380574, 0.1374978277611055, 0.1375402207481577, 0.13769138732871372, 0.13747128829598093, 0.1376112414052873, 0.13799079409170906, 0.13852738377144166, 0.13767782781143456, 0.1373861097048895, 0.13707683006881313, 0.18735659026808563, 0.13757309165505477, 0.13748971011470093, 0.13711503075485557, 0.13784232216885978, 0.1377910037882626, 0.1375360204743105, 0.1374268223875875, 0.13720804344001944, 0.13757565494341878, 0.1385250262288632, 0.13797544604380674, 0.13736033084921337, 0.13750770183572109, 0.13780252287091516, 0.13749111156408006, 0.1375801076503924, 0.1377876782115695, 0.1378149195242614, 0.13808687315326848, 0.13773408870285855, 0.1374885900275835, 0.13790078220249294, 0.13819065639820635, 0.13768789739698498, 0.13767690772715557, 0.13812549238495894, 0.1383888606713009]
# Random Forest generalization score: 0.13870663374537193
